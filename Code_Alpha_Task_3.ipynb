# %% [markdown]
# Task 3- Snake Game

# %%
import turtle
import time
import random

# %%
pip install keyboard
# Out:
# Requirement already satisfied: keyboard in ./opt/anaconda3/lib/python3.9/site-packages (0.13.5)
# Requirement already satisfied: pyobjc in ./opt/anaconda3/lib/python3.9/site-packages (from keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-EventKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-WebKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PushKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Vision==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Social==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-core==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PHASE==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MailKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-OSLog==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CallKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Metal==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Photos==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-GameController==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreData==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreText==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Automator==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Contacts==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PassKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Accounts==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Quartz==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MapKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreML==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-NetFS==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-GameKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-libxpc==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AdServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-AVKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Intents==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Security==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Network==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-Speech==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pyobjc->keyboard) (10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Score and delay
score = 0
high_score = 0
delay = 0.1


# Set up the screen
wn = turtle.Screen()
wn.title('Snake Game')
wn.bgcolor("black")
wn.setup(width=700, height=700)
wn.tracer(0)  # Turns off screen updates

# Outline of the playing field
pencil = turtle.Turtle()
pencil.speed(0)
pencil.shape('circle')
pencil.color('white')
pencil.penup()
pencil.hideturtle()
pencil.goto(310,310)
pencil.pendown()
pencil.goto(-310,310)
pencil.goto(-310,-310)
pencil.goto(310,-310)
pencil.goto(310,310)
pencil.penup()


# Snake head
head = turtle.Turtle()
head.speed(0)
head.shape("circle")
head.color('red')
head.penup()
head.goto(0,0)
head.direction = 'stop'

# Snake Food
food = turtle.Turtle()
food.speed(0)
food.shape("square")
food.color('green')
food.penup()
food.goto(0,100)

# Contains information about snake body
segments = []

# Pen
pen = turtle.Turtle()
pen.speed(0)
pen.shape('circle')
pen.color('white')
pen.penup()
pen.hideturtle()
pen.goto(0, 310)
pen.write('Score: 0 High Score: 0', align = 'center', font = ('Courier', 24, 'normal'))

### Functions
# Function to update the score
def update_score():
    pen.clear()
    pen.write('Score: {} High Score: {}'.format(score, high_score), align='center', font = ('Courier', 24, 'normal'))

# Functions that move snake in response to keyboard keys
def go_up():
    if head.direction != 'down':
        head.direction = 'up'
def go_down():
    if head.direction != 'up':
        head.direction = 'down'
def go_left():
    if head.direction != 'right':
        head.direction = 'left'
def go_right():
    if head.direction != 'left':
        head.direction = 'right'

# Function that helps the snake move
def move():
    # Move the end segments first in reverse order
    for index in range(len(segments)-1, 0, -1):
        x = segments[index-1].xcor()
        y = segments[index-1].ycor()
        segments[index].goto(x,y)
    # Move segment 0 to the head
    if len(segments) > 0:
        x = head.xcor()
        y = head.ycor()
        segments[0].goto(x,y)
    # Keep the snake moving in the same direction
    if head.direction == 'up':
        head.sety(head.ycor() + 10)
    if head.direction == 'down':
        head.sety(head.ycor() - 10)
    if head.direction == 'left':
        head.setx(head.xcor() - 10)
    if head.direction == 'right':
        head.setx(head.xcor() + 10)

# Function that tells the game what to do when collision occurs
def collision():
    time.sleep(0.5)
    head.goto(0,0)
    head.direction = 'stop'
    # Hide the segments
    for segment in segments:
        segment.hideturtle()
    # Clear the segments list
    segments.clear()
    score = 0
    update_score()
    # Reset the delay
    delay = 0.1

### Keyboard bindings
wn.listen()
wn.onkeypress(go_up, 'Up')
wn.onkeypress(go_down, 'Down')
wn.onkeypress(go_left, 'Left')
wn.onkeypress(go_right, 'Right')

### Loop that runs the game code
while True:
    # Updates the window repeatedly
    wn.update()

    # Check for collision with border
    if head.xcor()>290 or head.xcor()<-290 or head.ycor()>290 or head.ycor()<-290:
        collision()

    # Check if the snake eats the food
    if head.distance(food) < 20:
        # Move the food to a random spot
        food.goto(random.randint(-290,290),random.randint(-290,290))
        # Add a segment
        new_segment = turtle.Turtle()
        new_segment.speed(0)
        new_segment.shape('circle')
        new_segment.color("grey")
        new_segment.penup()
        segments.append(new_segment)
        # Shorten the delay - this increases speed of snake as it gets longer
        delay -= 0.001
        # Increase the score
        score += 10
        if score > high_score:
            high_score = score
        update_score()

    # Move the snake in the game
    move()

    # Check for head collision with the body segments
    for segment in segments:
        if segment.distance(head) < 10:
            collision()
    # Delay so that we can see things move
    time.sleep(delay)
    import keyboard
    #do stuff 
    if keyboard.is_pressed('Esc'):
        sys.exit()
# Makes the window visible and runs everythings
wn.mainloop()
# Out:
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Users/lathagovindarajan/opt/anaconda3/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/Users/lathagovindarajan/opt/anaconda3/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/lathagovindarajan/opt/anaconda3/lib/python3.9/site-packages/keyboard/__init__.py", line 294, in listen
#     _os_keyboard.listen(self.direct_callback)
#   File "/Users/lathagovindarajan/opt/anaconda3/lib/python3.9/site-packages/keyboard/_darwinkeyboard.py", line 430, in listen
#     raise OSError("Error 13 - Must be run as administrator")
# OSError: Error 13 - Must be run as administrator
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /var/folders/5h/qzc5g06j1g1g13j7pz0bbvz40000gn/T/ipykernel_31988/2426691405.py in <module>
#     151
#     152     # Move the snake in the game
# --> 153     move()
#     154
#     155     # Check for head collision with the body segments
#
# /var/folders/5h/qzc5g06j1g1g13j7pz0bbvz40000gn/T/ipykernel_31988/2426691405.py in move()
#      89         x = head.xcor()
#      90         y = head.ycor()
# ---> 91         segments[0].goto(x,y)
#      92     # Keep the snake moving in the same direction
#      93     if head.direction == 'up':
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in goto(self, x, y)
#    1775             self._goto(Vec2D(*x))
#    1776         else:
# -> 1777             self._goto(Vec2D(x, y))
#    1778
#    1779     def home(self):
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in _goto(self, end)
#    3158                       (self.currentLineItem,
#    3159                       self.currentLine[:],
# -> 3160                       screen._pointlist(self.currentLineItem),
#    3161                       self.items[:])
#    3162                       )
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in _pointlist(self, item)
#     752         (9.9999999999999982, 0.0)]
#     753         >>> """
# --> 754         cl = self.cv.coords(item)
#     755         pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     756         return  pl
#
# <string> in coords(self, *args, **kw)
#
# ~/opt/anaconda3/lib/python3.9/tkinter/__init__.py in coords(self, *args)
#    2764         return [self.tk.getdouble(x) for x in
#    2765                            self.tk.splitlist(
# -> 2766                    self.tk.call((self._w, 'coords') + args))]
#    2767
#    2768     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#
# TclError: invalid command name ".!canvas"
